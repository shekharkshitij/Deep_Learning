# %% [markdown]
# <a href="https://colab.research.google.com/github/shekharkshitij/Deep_Learning/blob/main/DL(Lab01).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #OR GATE Implementation using Single Perceptron

# %%
import numpy as np

# Define the OR gate truth table
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([0, 1, 1, 1])

# Initialize weights and bias
weights = np.random.rand(2)
bias = np.random.rand()

# Define the activation function (step function)
def step_function(x):
  return 1 if x >= 0 else 0

# Perceptron learning algorithm
learning_rate = 0.1
epochs = 10

for epoch in range(epochs):
  for i in range(len(X)):
    # Calculate weighted sum
    weighted_sum = np.dot(X[i], weights) + bias

    # Apply activation function
    prediction = step_function(weighted_sum)

    # Update weights and bias
    error = y[i] - prediction
    weights += learning_rate * error * X[i]
    bias += learning_rate * error

# Test the trained perceptron
for i in range(len(X)):
  prediction = step_function(np.dot(X[i], weights) + bias)
  print(f"Input: {X[i]}, Output: {prediction}")
# Out:
# Input: [0 0], Output: 0
# Input: [0 1], Output: 1
# Input: [1 0], Output: 1
# Input: [1 1], Output: 1

# %% [markdown]
# #NOR GATE Implementation using Single Perceptron

# %%
import numpy as np
# NOR GATE Implementation using Single Perceptron

# Define the NOR gate truth table
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([1, 0, 0, 0])  # NOR gate output

# Initialize weights and bias
weights = np.random.rand(2)
bias = np.random.rand()

# Define the activation function (step function)
def step_function(x):
  return 1 if x >= 0 else 0

# Perceptron learning algorithm
learning_rate = 0.1
epochs = 10

for epoch in range(epochs):
  for i in range(len(X)):
    # Calculate weighted sum
    weighted_sum = np.dot(X[i], weights) + bias

    # Apply activation function
    prediction = step_function(weighted_sum)

    # Update weights and bias
    error = y[i] - prediction
    weights += learning_rate * error * X[i]
    bias += learning_rate * error

# Test the trained perceptron
for i in range(len(X)):
  prediction = step_function(np.dot(X[i], weights) + bias)
  print(f"Input: {X[i]}, Output: {prediction}")
# Out:
# Input: [0 0], Output: 1
# Input: [0 1], Output: 0
# Input: [1 0], Output: 0
# Input: [1 1], Output: 0

# %% [markdown]
# #NAND GATE Implementation using Single Perceptron

# %%
# NAND GATE Implementation using Single Perceptron

# Define the NAND gate truth table
X = np.array([[0, 0], [0, 1], [1, 0], [1, 1]])
y = np.array([1, 1, 1, 0])  # NAND gate output

# Initialize weights and bias
weights = np.random.rand(2)
bias = np.random.rand()

# Define the activation function (step function)
def step_function(x):
  return 1 if x >= 0 else 0

# Perceptron learning algorithm
learning_rate = 0.1
epochs = 10

for epoch in range(epochs):
  for i in range(len(X)):
    # Calculate weighted sum
    weighted_sum = np.dot(X[i], weights) + bias

    # Apply activation function
    prediction = step_function(weighted_sum)

    # Update weights and bias
    error = y[i] - prediction
    weights += learning_rate * error * X[i]
    bias += learning_rate * error

# Test the trained perceptron
for i in range(len(X)):
  prediction = step_function(np.dot(X[i], weights) + bias)
  print(f"Input: {X[i]}, Output: {prediction}")
# Out:
# Input: [0 0], Output: 1
# Input: [0 1], Output: 1
# Input: [1 0], Output: 1
# Input: [1 1], Output: 0

# %% [markdown]
# #Loading Dataset using Kaggle API

# %%
from google.colab import files
import os

# Upload kaggle.json
uploaded = files.upload()

# Create the .kaggle directory if it doesn't exist
os.makedirs('/root/.kaggle', exist_ok=True)

# Move kaggle.json to the .kaggle directory
os.rename('kaggle.json', '/root/.kaggle/kaggle.json')

# Set correct permissions for kaggle.json
# !chmod 600 /root/.kaggle/kaggle.json

# Verify kaggle.json placement
# !ls -l /root/.kaggle
# Out:
#      <input type="file" id="files-250c93bc-cac7-440e-af45-b12042e0b2bd" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-250c93bc-cac7-440e-af45-b12042e0b2bd">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import kaggle
import zipfile
import pandas as pd

# Dataset identifier from Kaggle URL
dataset = 'yasserh/wine-quality-dataset'
destination = 'wine-quality-dataset.zip'

# Download the dataset from Kaggle
kaggle.api.dataset_download_files(dataset, path='.', unzip=False)

# Extract the dataset from the zip file
with zipfile.ZipFile(destination, 'r') as zip_ref:
    zip_ref.extractall('.')

# Read the dataset into a DataFrame with correct delimiter
df_wine = pd.read_csv('winequality-red.csv', sep=';')

# Display the first few rows of the dataset
print("Wine Quality Dataset:")
print(df_wine.head())
# Out:
# 2024-07-25 14:55:08,915 WARNING Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'RemoteDisconnected('Remote end closed connection without response')': /api/v1/datasets/download/yasserh/wine-quality-dataset?datasetVersionNumber=None
# WARNING:urllib3.connectionpool:Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'RemoteDisconnected('Remote end closed connection without response')': /api/v1/datasets/download/yasserh/wine-quality-dataset?datasetVersionNumber=None
# Dataset URL: https://www.kaggle.com/datasets/yasserh/wine-quality-dataset
# Wine Quality Dataset:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# ...

# %% [markdown]
# #Loading Dataset using GitHub

# %%
import pandas as pd
import requests

# URL of the raw dataset on GitHub
dataset_url = 'https://raw.githubusercontent.com/shrikant-temburwar/Wine-Quality-Dataset/master/winequality-red.csv'

# Download the dataset
response = requests.get(dataset_url)

# Save the dataset locally
with open('winequality-red.csv', 'wb') as file:
    file.write(response.content)

# Read the dataset into a DataFrame with correct delimiter
df_wine = pd.read_csv('winequality-red.csv', sep=';')

# Display the first few rows of the dataset
print("Wine Quality Dataset:")
print(df_wine.head())
# Out:
# Wine Quality Dataset:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# ...

# %% [markdown]
# # Classification of Fashion MNIST Dataset(provided in TFDS) using MLP

# %%
import tensorflow as tf
import tensorflow_datasets as tfds
from tensorflow.keras import layers, models

# Load the dataset
(ds_train, ds_test), ds_info = tfds.load('fashion_mnist', split=['train', 'test'], shuffle_files=True, as_supervised=True, with_info=True)

# Normalize the data
def normalize_img(image, label):
    return tf.cast(image, tf.float32) / 255.0, label

ds_train = ds_train.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.cache()
ds_train = ds_train.shuffle(ds_info.splits['train'].num_examples)
ds_train = ds_train.batch(128)
ds_train = ds_train.prefetch(tf.data.AUTOTUNE)

ds_test = ds_test.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
ds_test = ds_test.batch(128)
ds_test = ds_test.cache()
ds_test = ds_test.prefetch(tf.data.AUTOTUNE)

# Define the model
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(10)
])

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

# Train the model
model.fit(
    ds_train,
    epochs=10,
    validation_data=ds_test,
)

# Evaluate the model
model.evaluate(ds_test)
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# ...
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/fashion_mnist/incomplete.2VVAWV_3.0.1/fashion_mnist-train.tfrecord*...:   …
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/fashion_mnist/incomplete.2VVAWV_3.0.1/fashion_mnist-test.tfrecord*...:   0…
# Dataset fashion_mnist downloaded and prepared to /root/tensorflow_datasets/fashion_mnist/3.0.1. Subsequent calls will reuse this data.
# Epoch 1/10
# 469/469 [==============================] - 12s 11ms/step - loss: 0.5534 - sparse_categorical_accuracy: 0.8087 - val_loss: 0.4366 - val_sparse_categorical_accuracy: 0.8432
# Epoch 2/10
# ...

# %% [markdown]
# # Classification of KMNIST Dataset(provided in TFDS) using MLP

# %%
# Load the dataset
(ds_train, ds_test), ds_info = tfds.load('kmnist', split=['train', 'test'], shuffle_files=True, as_supervised=True, with_info=True)

# Normalize the data
def normalize_img(image, label):
    return tf.cast(image, tf.float32) / 255.0, label

ds_train = ds_train.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.cache()
ds_train = ds_train.shuffle(ds_info.splits['train'].num_examples)
ds_train = ds_train.batch(128)
ds_train = ds_train.prefetch(tf.data.AUTOTUNE)

ds_test = ds_test.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
ds_test = ds_test.batch(128)
ds_test = ds_test.cache()
ds_test = ds_test.prefetch(tf.data.AUTOTUNE)

# Define the model
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(10)
])

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

# Train the model
model.fit(
    ds_train,
    epochs=10,
    validation_data=ds_test,
)

# Evaluate the model
model.evaluate(ds_test)
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# ...
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/kmnist/incomplete.OWJSMO_3.0.1/kmnist-train.tfrecord*...:   0%|          |…
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/kmnist/incomplete.OWJSMO_3.0.1/kmnist-test.tfrecord*...:   0%|          | …
# Dataset kmnist downloaded and prepared to /root/tensorflow_datasets/kmnist/3.0.1. Subsequent calls will reuse this data.
# Epoch 1/10
# 469/469 [==============================] - 9s 7ms/step - loss: 0.4903 - sparse_categorical_accuracy: 0.8540 - val_loss: 0.5918 - val_sparse_categorical_accuracy: 0.8188
# Epoch 2/10
# ...

# %% [markdown]
# #Classification of MNIST Corrupted Dataset(provided in TFDS) using MLP

# %%
# Load the dataset
(ds_train, ds_test), ds_info = tfds.load('mnist_corrupted/identity', split=['train', 'test'], shuffle_files=True, as_supervised=True, with_info=True)

# Normalize the data
def normalize_img(image, label):
    return tf.cast(image, tf.float32) / 255.0, label

ds_train = ds_train.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
ds_train = ds_train.cache()
ds_train = ds_train.shuffle(ds_info.splits['train'].num_examples)
ds_train = ds_train.batch(128)
ds_train = ds_train.prefetch(tf.data.AUTOTUNE)

ds_test = ds_test.map(normalize_img, num_parallel_calls=tf.data.AUTOTUNE)
ds_test = ds_test.batch(128)
ds_test = ds_test.cache()
ds_test = ds_test.prefetch(tf.data.AUTOTUNE)

# Define the model
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(10)
])

# Compile the model
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.SparseCategoricalAccuracy()],
)

# Train the model
model.fit(
    ds_train,
    epochs=10,
    validation_data=ds_test,
)

# Evaluate the model
model.evaluate(ds_test)
# Out:
# ...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# ...
# Generating train examples...:   0%|          | 0/60000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/mnist_corrupted/identity/incomplete.Z0PSYY_1.0.0/mnist_corrupted-train.tfr…
# Generating test examples...:   0%|          | 0/10000 [00:00<?, ? examples/s]
# Shuffling /root/tensorflow_datasets/mnist_corrupted/identity/incomplete.Z0PSYY_1.0.0/mnist_corrupted-test.tfre…
# Dataset mnist_corrupted downloaded and prepared to /root/tensorflow_datasets/mnist_corrupted/identity/1.0.0. Subsequent calls will reuse this data.
# Epoch 1/10
# 469/469 [==============================] - 10s 6ms/step - loss: 0.3366 - sparse_categorical_accuracy: 0.9047 - val_loss: 0.1639 - val_sparse_categorical_accuracy: 0.9516
# Epoch 2/10
# ...
